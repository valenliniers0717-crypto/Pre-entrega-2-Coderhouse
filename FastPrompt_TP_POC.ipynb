# %% [markdown]
# # FastPrompt-TP — Proof of Concept (POC)
# Automatización de textos de marketing para Traducción Pública EN<>ES.

# %%
# Configuración básica (placeholder)
api_key = "YOUR_API_KEY"
model_name = "gpt-4o-mini"  # Ejemplo

# %% [markdown]
# ## Prompt maestro

# %%
master_prompt = '''
Contexto:
Sos un asistente experto en marketing para servicios profesionales lingüísticos EN<>ES.

Rol:
Actuás como copywriter senior y estratega de comunicación.

Tarea:
A partir del brief provisto, generá:
- descripción del servicio
- beneficios
- propuesta de valor
- 5 copies para redes sociales
- 5 CTAs
- email profesional para solicitar cotización

Formato:
Devolver en JSON estructurado.

Tono:
Profesional, claro, orientado a clientes corporativos y particulares.
'''

brief = {
    "servicio": "Traducción Pública EN<>ES",
    "target": "clientes particulares y legales",
    "diferencial": "precisión terminológica y rapidez"
}

# %% [markdown]
# ## Llamada simulada

# %%
# Esta celda ilustraría la llamada a la API
response = {
    "descripcion": "Servicio profesional de Traducción Pública EN<>ES...",
    "beneficios": ["Precisión terminológica", "Entrega rápida"],
    "propuesta_valor": "Garantía de fidelidad legal y calidad lingüística",
    "copies": ["Copy 1...", "Copy 2...", "..."],
    "ctas": ["Contactame hoy", "Solicitá tu cotización"],
    "email": "Estimado cliente, adjunto encontrará..."
}

response
